# %% [markdown]
# # What is Pandas.

# %% [markdown]
# Pandas is a Python library used for working with data sets.

# %% [markdown]
# The name "Pandas" has a reference to both "Panel Data"

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.2.4

# %%
z={
    "Name":["Deepak","Pravin","Mohit"],
   "Age":[22,25,23],
   "marks":[20,50,40]
  }

# %%
print(z)
# Out:
# {'Name': ['Deepak', 'Pravin', 'Mohit'], 'Age': [22, 25, 23], 'marks': [20, 50, 40]}

# %%
df=pd.DataFrame(z)
df
# Out:
#      Name  Age  marks
# 0  Deepak   22     20
# 1  Pravin   25     50
# 2   Mohit   23     40

# %%
df["Name"][0]
# Out:
# 'Deepak'

# %%
df
# Out:
#      Name  Age  marks
# 0  Deepak   22     20
# 1  Pravin   25     50
# 2   Mohit   23     40

# %%
df["Name"][2]
# Out:
# 'Mohit'

# %%
df.Name
df['Name']
# Out:
# 0    Deepak
# 1    Pravin
# 2     Mohit
# Name: Name, dtype: object

# %%
df["Name"][2]="raju"
# Out:
# <ipython-input-6-874ff7f9e76c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Name"][2]="raju"

# %%
df
# Out:
#      Name  Age  marks
# 0  Deepak   22     20
# 1  Pravin   25     50
# 2    raju   23     40

# %%
#storing the data
#.csv(coma seperated value)
#.xlsx(excel)

# %%
file=df.to_csv('file.csv')

# %%
z={
    "Name":["Deepak","Pravin","Mohit"],
   "Age":[22,25,23],
   "marks":[20,50,40]
  }

# %%
d=pd.DataFrame(z)

# %%
d

# %% [markdown]
# # storing the data

# %%
#.csv---->>comma sepereted value
#.xlsx--->>excel

# %% [markdown]
# # To save the file in .csv format

# %%
new=d.to_csv("new_file.csv")

# %% [markdown]
# # To read the file

# %%
read_file=pd.read_csv(r'new_file.csv')

# %%
read_file
# Out:
#    Unnamed: 0    Name  Age  marks
# 0           0  Deepak   22     20
# 1           1  Pravin   25     50
# 2           2   Mohit   23     40

# %%
d={
    "name":["Deepak","pravin","rahul"],
    "age":[22,23,27],
    "salary":[50000,60000,45000]
}
x=pd.DataFrame(d)
print(x)
# Out:
#      name  age  salary
# 0  Deepak   22   50000
# 1  pravin   23   60000
# 2   rahul   27   45000

# %%
x['name'][1]='raj'
# Out:
# <ipython-input-13-0f938f8f5bb8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['name'][1]='raj'

# %%
x
# Out:
#      name  age  salary
# 0  Deepak   22   50000
# 1     raj   23   60000
# 2   rahul   27   45000

# %% [markdown]
# # read csv file

# %%
data=pd.read_csv(r'E:\Data_for_Analysis\age_of_marriage_data.csv')

# %%
data
# Out:
#         id  gender height   religion        caste mother_tongue  \
# 0        1  female   5'4"        NaN       others        Telugu
# 1        2    male   5'7"       Jain   Shwetamber      Gujarati
# 2        3    male   5'7"      Hindu      Brahmin         Hindi
# 3        4  female   5'0"      Hindu       Thakur         Hindi
# 4        5    male   5'5"  Christian   Born Again     Malayalam
# ...    ...     ...    ...        ...          ...           ...
# 2562  2563  female   5'3"      Hindu       Thakur         Hindi
# 2563  2564    male  5'11"      Hindu       Thakur         Hindi
# 2564  2565  female   5'3"      Hindu      Baishya       Bengali
# 2565  2566  female  4'11"        NaN       others        Telugu
# 2566  2567  female   5'2"  Christian     Marthoma     Malayalam
#
#                             profession               location  \
# 0                                  NaN                 London
# 1     Doctor / Healthcare Professional            Fairfax- VA
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2567 entries, 0 to 2566
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2567 non-null   int64
#  1   gender           2538 non-null   object
#  2   height           2449 non-null   object
#  3   religion         1932 non-null   object
#  4   caste            2425 non-null   object
#  5   mother_tongue    2403 non-null   object
#  6   profession       2237 non-null   object
#  7   location         2412 non-null   object
#  8   country          2551 non-null   object
#  9   age_of_marriage  2548 non-null   float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 200.7+ KB

# %%
data.iloc[2:6]
# Out:
#    id  gender height   religion        caste mother_tongue  \
# 2   3    male   5'7"      Hindu      Brahmin         Hindi
# 3   4  female   5'0"      Hindu       Thakur         Hindi
# 4   5    male   5'5"  Christian   Born Again     Malayalam
# 5   6    male   5'5"      Hindu      Valmiki         Hindi
#
#                        profession         location country  age_of_marriage
# 2       Entrepreneurs / Business         Begusarai   India             32.0
# 3                       Architect           Mumbai   India             30.0
# 4  Sales Professional / Marketing  Sulthan Bathery   India             30.0
# 5                       Sportsman            Delhi   India             29.0

# %%
data.iloc[2:6,1:6] #[row-1:row5,col-1:col4]
# Out:
#    gender height   religion        caste mother_tongue
# 2    male   5'7"      Hindu      Brahmin         Hindi
# 3  female   5'0"      Hindu       Thakur         Hindi
# 4    male   5'5"  Christian   Born Again     Malayalam
# 5    male   5'5"      Hindu      Valmiki         Hindi

# %% [markdown]
# # read excel file

# %%
data1=pd.read_excel(r'C:\Users\Deepak kumar\Downloads\P6-SuperStoreUS-2015.xlsx')

# %%
data1

# %%
new_file={
    "name":["Deepak"],
    "age":[22],
    "salary":[25000]
}

# %%
new=pd.DataFrame(new_file)
print(new)

# %%
file={
    "name":["Deepak","pra"],
    "age":[22,23],
    "salary":[25000,25400]
}

# %%
d=pd.DataFrame(file)
print(d)

# %%
x=[5,6,8,9,10]
a=pd.Series(x)
print(x)

# %% [markdown]
# # Part-2

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r'E:\Data_for_Analysis\25_Complaints_against_police.csv')
df
# Out:
#                      Area_Name  Year                            Sub_group  \
# 0    Andaman & Nicobar Islands  2001  Complaints Against Police Personnel
# 1               Andhra Pradesh  2001  Complaints Against Police Personnel
# 2            Arunachal Pradesh  2001  Complaints Against Police Personnel
# 3                        Assam  2001  Complaints Against Police Personnel
# 4                        Bihar  2001  Complaints Against Police Personnel
# ..                         ...   ...                                  ...
# 345                 Tamil Nadu  2010  Complaints Against Police Personnel
# 346                    Tripura  2010  Complaints Against Police Personnel
# 347              Uttar Pradesh  2010  Complaints Against Police Personnel
# 348                Uttarakhand  2010  Complaints Against Police Personnel
# 349                West Bengal  2010  Complaints Against Police Personnel
#
#      CPA_-_Cases_Registered  CPA_-_Cases_Reported_for_Dept._Action  \
# ...

# %%
df.head()
# Out:
#                    Area_Name  Year                            Sub_group  \
# 0  Andaman & Nicobar Islands  2001  Complaints Against Police Personnel
# 1             Andhra Pradesh  2001  Complaints Against Police Personnel
# 2          Arunachal Pradesh  2001  Complaints Against Police Personnel
# 3                      Assam  2001  Complaints Against Police Personnel
# 4                      Bihar  2001  Complaints Against Police Personnel
#
#    CPA_-_Cases_Registered  CPA_-_Cases_Reported_for_Dept._Action  \
# 0                      10                                      4
# 1                    3078                                     72
# 2                      24                                     39
# 3                      17                                      3
# 4                       1                                      1
#
#    CPA_-_Complaints/Cases_Declared_False/Unsubstantiated  \
# 0                                                  0
# ...

# %%
df.head(7)
# Out:
#                    Area_Name  Year                            Sub_group  \
# 0  Andaman & Nicobar Islands  2001  Complaints Against Police Personnel
# 1             Andhra Pradesh  2001  Complaints Against Police Personnel
# 2          Arunachal Pradesh  2001  Complaints Against Police Personnel
# 3                      Assam  2001  Complaints Against Police Personnel
# 4                      Bihar  2001  Complaints Against Police Personnel
# 5                 Chandigarh  2001  Complaints Against Police Personnel
# 6               Chhattisgarh  2001  Complaints Against Police Personnel
#
#    CPA_-_Cases_Registered  CPA_-_Cases_Reported_for_Dept._Action  \
# 0                      10                                      4
# 1                    3078                                     72
# 2                      24                                     39
# 3                      17                                      3
# ...

# %%
df.tail()

# %%
df.tail(10)

# %%
df.sample()  #it will return random any data from table

# %%
df.sample(5)

# %%
numarical data
categorical data

# %%
percentage
percentile

# %%
df.describe()
# Out:
#               Year  CPA_-_Cases_Registered  \
# count   350.000000              350.000000
# mean   2005.500000              257.465714
# std       2.876393              963.522756
# min    2001.000000                0.000000
# 25%    2003.000000                3.000000
# 50%    2005.500000               17.500000
# 75%    2008.000000               98.750000
# max    2010.000000             8701.000000
#
#        CPA_-_Cases_Reported_for_Dept._Action  \
# count                             350.000000
# mean                              161.368571
# std                               682.832843
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 6.000000
# 75%                                64.000000
# max                              8326.000000
#
#        CPA_-_Complaints/Cases_Declared_False/Unsubstantiated  \
# count                                         350.000000
# ...

# %%
df.isnull()  #To check null value
# Out:
#      Area_Name   Year  Sub_group  CPA_-_Cases_Registered  \
# 0        False  False      False                   False
# 1        False  False      False                   False
# 2        False  False      False                   False
# 3        False  False      False                   False
# 4        False  False      False                   False
# ..         ...    ...        ...                     ...
# 345      False  False      False                   False
# 346      False  False      False                   False
# 347      False  False      False                   False
# 348      False  False      False                   False
# 349      False  False      False                   False
#
#      CPA_-_Cases_Reported_for_Dept._Action  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ...

# %%
df.isnull().sum()
# Out:
# Area_Name                                                          0
# Year                                                               0
# Sub_group                                                          0
# CPA_-_Cases_Registered                                             0
# CPA_-_Cases_Reported_for_Dept._Action                              0
# CPA_-_Complaints/Cases_Declared_False/Unsubstantiated              0
# CPA_-_Complaints_Received/Alleged                                  0
# CPA_-_No_of_Departmental_Enquiries                                 0
# CPA_-_No_of_Magisterial_Enquiries                                  0
# CPA-_Cases_Sent_for_Trials/Charge-sheeted                          0
# CPA-_No_of_Judicial_Enquiries                                      0
# CPB_-_Police_Personnel_Acquitted                                   0
# CPB_-_Police_Personnel_Convicted                                   0
# CPB_-_Police_Personnel_sent_up_for_Trial                           0
# ...

# %%
df.notnull()
# Out:
#      Area_Name  Year  Sub_group  CPA_-_Cases_Registered  \
# 0         True  True       True                    True
# 1         True  True       True                    True
# 2         True  True       True                    True
# 3         True  True       True                    True
# 4         True  True       True                    True
# ..         ...   ...        ...                     ...
# 345       True  True       True                    True
# 346       True  True       True                    True
# 347       True  True       True                    True
# 348       True  True       True                    True
# 349       True  True       True                    True
#
#      CPA_-_Cases_Reported_for_Dept._Action  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                     True
# 4                                     True
# ...

# %%
df1=pd.read_csv(r'E:\Data_for_Analysis\framingham.csv')
df1
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df1.isnull().any() #if null values is available then True
# Out:
# male               False
# age                False
# education           True
# currentSmoker      False
# cigsPerDay          True
# BPMeds              True
# prevalentStroke    False
# prevalentHyp       False
# diabetes           False
# totChol             True
# sysBP              False
# diaBP              False
# BMI                 True
# heartRate           True
# glucose             True
# TenYearCHD         False
# dtype: bool

# %%
df1.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df1.notnull().sum()
# Out:
# male               4240
# age                4240
# education          4135
# currentSmoker      4240
# cigsPerDay         4211
# BPMeds             4187
# prevalentStroke    4240
# prevalentHyp       4240
# diabetes           4240
# totChol            4190
# sysBP              4240
# diaBP              4240
# BMI                4221
# heartRate          4239
# glucose            3852
# TenYearCHD         4240
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
df1['education'].isnull().sum()
# Out:
# 105

# %%
df2=df1.dropna() #to delete the NaN value

# %%
df2
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df2.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
data1=pd.read_excel('E:\Data_for_Analysis\data.xlsx')
data1
# Out:
#       name   age  marks
# 0   deepak  23.0   77.0
# 1  praveen  22.0   98.0
# 2    mohit  24.0   78.0
# 3     raju  25.0   89.0
# 4   vikash  26.0   65.0
# 5      NaN  20.0  100.0
# 6   girish  28.0    NaN
# 7    rahul   NaN   64.0

# %% [markdown]
# # na_values=['no value','##']

# %%
import pandas as pd

# %%
df4=pd.read_excel('E:\Data_for_Analysis\data2.xlsx',na_values=['no value','##'])  # to fill NaN where written "no value" and "##"
df4
# Out:
#        name   age  marks
# 0    deepak  23.0   77.0
# 1   praveen  22.0   98.0
# 2     mohit   NaN   78.0
# 3      raju  25.0   89.0
# 4    vikash  26.0   65.0
# 5  no valus  20.0  100.0
# 6    girish  28.0    NaN
# 7     rahul   NaN   64.0

# %%
data=pd.read_excel(r'C:\Users\Deepak kumar\Downloads\smalldata.xlsx')

# %%
data
# Out:
#   Name   Age  Marks
# 0    A  22.0  100.0
# 1    B  34.0   78.0
# 2    C   NaN   67.0
# 3    D  89.0    NaN
# 4    E  67.0   35.0
# 5    F  55.0    NaN
