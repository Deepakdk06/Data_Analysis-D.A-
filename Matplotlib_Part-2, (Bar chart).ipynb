# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([4,5,8,9,10,2,17])
y=np.array([3,8,9,10,15,3,15])
days=np.array(["Sun","Mon","tue","wed","thur","fri","sat"])
plt.title("Temperature days wise")
plt.plot(days,x,y)
plt.show()

# %%
subject=(["maths","AI","PYthon","English","DBMS"])
Sec_A=np.array([23,45,12,19,54])
sec_B=np.array([78,54,65,45,44])
Sec_C=np.array([54,25,74,65,65])
plt.bar(subject,Sec_A)
plt.show()

# %%
plt.bar(subject,sec_B)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(subject,Sec_C)
# Out:
# <BarContainer object of 5 artists>

# %%
sum_of_sec=np.sum([Sec_A,sec_B,Sec_C],0)

# %%
sum_of_sec
# Out:
# array([155, 124, 151, 129, 163])

# %%
plt.bar(subject,sum_of_sec)
# Out:
# <BarContainer object of 5 artists>

# %%
#city,location,population
# max. min and avg population
Delhi_Population = [23,45,78]
Noida_Population = [90,50,67]
Azamgarh_Population = [23,45,77]
city = ['Delhi','Noida','Azamgarh']
plt.bar(city,Delhi_Population)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(city,Noida_Population)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(city,Azamgarh_Population)
# Out:
# <BarContainer object of 3 artists>

# %%
sum_of_population=np.sum([Delhi_Population,Noida_Population,Azamgarh_Population],0)

# %%
sum_of_population
# Out:
# array([136, 140, 222])

# %%
plt.bar(city,sum_of_population)
# Out:
# <BarContainer object of 3 artists>

# %%
Delhi_Population = [23,45,78]
Noida_Population = [90,50,67]
Azamgarh_Population = [23,45,77]
city = ['Delhi','Noida','Azamgarh']
plt.title("Population of Delhi, Noida and Azamgarh",fontsize=18,color='b')
plt.ylabel("Cities",fontsize=15,color='r')
plt.xlabel("Population",fontsize=15,color='r')
plt.barh(city,sum_of_population,color='green',edgecolor='r',height = 0.6,align='edge')
plt.legend('ylabel')

# %%
plt.bar(city,sum_of_population,color='m',width = 0.4)
# Out:
# <BarContainer object of 3 artists>

# %%
a=sum_of_population.min()
a
# Out:
# 136

# %%
b=sum_of_population.max()
b
# Out:
# 222

# %%
c=sum_of_population.mean()
c
# Out:
# 166.0

# %%
city=['Delhi','Beijing','Washington','Tokyo','Moscow']
Gender=['Male','Female']
#pos = np.arange(len(city))
bar_width = 0.35
Happiness_Index_Male=[60,40,70,65,85]
Happiness_Index_Female=[30,60,70,55,75]
plt.bar(pos,Happiness_Index_Male,bar_width,color='blue',edgecolor='black')
plt.bar(pos+bar_width,Happiness_Index_Female,bar_width,color='pink',edgecolor='black')
plt.xticks(pos, city)
plt.xlabel('City', fontsize=16)
plt.ylabel('Happiness_Index', fontsize=16)
plt.title('Group Barchart - Happiness index across cities By Gender',fontsize=18)
#plt.legend(Gender,loc=2)
plt.show()
